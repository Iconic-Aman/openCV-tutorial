# %%
import cv2 as cv
img = cv.imread('img.jpg', 0)

# %%
cv.imshow('Image',img)
cv.waitKey(2000)  #2000 millisecond = 2sec
cv.destroyAllWindows()

# %% [markdown]
# ### Using Matplotlib

# %%
import matplotlib.pyplot as plt
plt.imshow(img)
